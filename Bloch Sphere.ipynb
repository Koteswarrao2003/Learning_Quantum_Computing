# %%
from qiskit import *
from qiskit.visualization import plot_bloch_multivector
from qiskit.visualization import plot_histogram
# %matplotlib inline
import math

# %%
from qiskit_aer import Aer

# %%
Aer.backends()
# Out:
# [AerSimulator('aer_simulator'),
#  AerSimulator('aer_simulator_statevector'),
#  AerSimulator('aer_simulator_density_matrix'),
#  AerSimulator('aer_simulator_stabilizer'),
#  AerSimulator('aer_simulator_matrix_product_state'),
#  AerSimulator('aer_simulator_extended_stabilizer'),
#  AerSimulator('aer_simulator_unitary'),
#  AerSimulator('aer_simulator_superop'),
#  QasmSimulator('qasm_simulator'),
#  StatevectorSimulator('statevector_simulator'),
#  UnitarySimulator('unitary_simulator')]

# %%
qasm_simulator=Aer.get_backend('qasm_simulator')
statevector_simulator=Aer.get_backend('statevector_simulator')

# %%
from qiskit import transpile
from qiskit.quantum_info import Statevector
from qiskit_aer import AerSimulator

# %%
def run_on_simulator(circuit):
    state=Statevector.from_instruction(circuit)
    circuit_copy=circuit.copy()
    num_qubits=circuit.num_qubits
    circuit_copy.measure([i for i in range(num_qubits)],[i for i in range(num_qubits)])

    simulator=AerSimulator()
    compiled=transpile(circuit_copy,simulator)

    result=simulator.run(compiled, shots=1024).result()
    count=result.get_counts()

    return state,count

# %%
circuit=QuantumCircuit(2,2)
state, count=run_on_simulator(circuit)

# %%
plot_bloch_multivector(state)

# %%
circuit.h(0)
state, count=run_on_simulator(circuit)
plot_bloch_multivector(state)

# %%
plot_histogram(count)

# %%
circuit=QuantumCircuit(2,2)
circuit.h(0)
circuit.cx(0,1)
state, count=run_on_simulator(circuit)
plot_bloch_multivector(state)

# %%
plot_histogram(count)

# %%
circuit=QuantumCircuit(2,2)
circuit.rx(math.pi/4,0)
circuit.rx(math.pi/2,1)
state, count=run_on_simulator(circuit)
plot_bloch_multivector(state)

# %%
circuit=QuantumCircuit(2,2)
circuit.rx(math.pi/12,0)
circuit.rx(math.pi/8,1)
state, count=run_on_simulator(circuit)
plot_bloch_multivector(state)

# %%
circuit=QuantumCircuit(2,2)
circuit.ry(math.pi/4,0)
circuit.ry(math.pi/2,1)
state, count=run_on_simulator(circuit)
plot_bloch_multivector(state)

# %%
circuit=QuantumCircuit(1,1)
circuit.h(0)
state, count=run_on_simulator(circuit)
plot_bloch_multivector(state)

# %%
circuit=QuantumCircuit(1,1)
circuit.h(0)
circuit.z(0)
state, count=run_on_simulator(circuit)
plot_bloch_multivector(state)

# %%
plot_histogram([count])
